# %%
import pandas as pd
import numpy as np

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Shaik Mohammed Awaiz\AppData\Local\Programs\Python\Python310\python.exe

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3
